# %% [markdown]
# **BIG BIG HINT! Look in the instructions to guide you on this task.**

# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# load CSV file

file="Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read csv file with pandas

svyclean_data_df=pd.read_csv(file, encoding = 'iso-8859-1', low_memory=False)
svyclean_data_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
# Inspect all columns of dataframe

svyclean_data_df.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampFullJobAfter',
#        'BootcampLoanYesNo', 'BootcampMonthsAgo', 'BootcampName',
#        'BootcampPostSalary', 'BootcampRecommend', 'ChildrenNumber',
#        ...
#        'ResourceSoloLearn', 'ResourceStackOverflow', 'ResourceTreehouse',
#        'ResourceUdacity', 'ResourceUdemy', 'ResourceW3Schools',
#        'ResourceYouTube', 'SchoolDegree', 'SchoolMajor', 'StudentDebtOwe'],
#       dtype='object', length=113)

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
reduced_svyclean_df=svyclean_data_df.iloc[:,[0, 1, 2, 3, 4, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
reduced_svyclean_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# 1                NaN                 NaN                NaN             NaN
# 2                NaN                 NaN                NaN             NaN
# 3                NaN                 NaN                NaN             NaN
# 4                NaN                 NaN                NaN             NaN
#
#                   CityPopulation  CodeEventBootcamp               CountryLive  \
# ...

# %%
# Change "0" to "No" and "1" to "Yes" in response columns
reduced_svyclean_df=reduced_svyclean_df.replace({0.0: "No", 1.0: "Yes"})
reduced_svyclean_df.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 0               NaN                 NaN               NaN            NaN
# 1               NaN                 NaN               NaN            NaN
# 2               NaN                 NaN               NaN            NaN
# 3               NaN                 NaN               NaN            NaN
# 4               NaN                 NaN               NaN            NaN
#
#                   CityPopulation CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million               NaN  United States of America
# ...

# %%
# Calculate total number of respondents in survey

respondents=len(reduced_svyclean_df)
respondents
# Out:
# 15620

# %%
# Extract rows corresponding only to people who attended a bootcamp
reduced_svyclean_df[['AttendedBootcamp','BootcampFinish','BootcampFullJobAfter','BootcampLoanYesNo','BootcampPostSalary']]
# Out:
#       AttendedBootcamp BootcampFinish BootcampFullJobAfter BootcampLoanYesNo  \
# 0                   No            NaN                  NaN               NaN
# 1                   No            NaN                  NaN               NaN
# 2                   No            NaN                  NaN               NaN
# 3                   No            NaN                  NaN               NaN
# 4                   No            NaN                  NaN               NaN
# ...                ...            ...                  ...               ...
# 15615               No            NaN                  NaN               NaN
# 15616               No            NaN                  NaN               NaN
# 15617               No            NaN                  NaN               NaN
# 15618               No            NaN                  NaN               NaN
# 15619               No            NaN                  NaN               NaN
#
#        BootcampPostSalary
# ...

# %%
#  Create a new df for "bootcamp_attended" with the columns.
boot_camp_attendees_df=reduced_svyclean_df[reduced_svyclean_df.AttendedBootcamp=="Yes"]
boot_camp_attendees_df.head()
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93   32.0              Yes            Yes                   No
# 97   26.0              Yes            Yes                  Yes
# 130  41.0              Yes            Yes                  Yes
# 159  26.0              Yes            Yes                   No
# 188  24.0              Yes             No                  NaN
#
#     BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 93                 No                 NaN                No            NaN
# 97                 No             45000.0                No            NaN
# 130               Yes             75000.0               Yes              3
# 159                No                 NaN                No            NaN
# 188               Yes                 NaN                No            NaN
#
#                     CityPopulation CodeEventBootcamp  \
# 93   between 100,000 and 1 million               NaN
# ...

# %%
# Calculate average age of attendees
avg_age_attendees= boot_camp_attendees_df['Age'].mean()
avg_age_attendees
# Out:
# 31.066014669926652

# %%
# Calculate how many people attended a bootcamp
boot_camp_attendees_df['AttendedBootcamp'].count()
# Out:
# 953

# %%
#calculate length of rows to find total attendies

total_attendees=len(boot_camp_attendees_df)
total_attendees
# Out:
# 953

# %%
# School degrees

boot_camp_attendees_df['SchoolDegree'].unique()
# Out:
# array(["bachelor's degree", "master's degree (non-professional)",
#        'some college credit, no degree',
#        'professional degree (MBA, MD, JD, etc.)', "associate's degree",
#        'trade, technical, or vocational training',
#        'high school diploma or equivalent (GED)', nan,
#        'no high school (secondary school)', 'Ph.D.', 'some high school'],
#       dtype=object)

# %%
# Calculate how many attendees hold degrees

attendees_schl_degree=boot_camp_attendees_df['SchoolDegree'].count()
attendees_schl_degree
# Out:
# 832

# %%
# Count number of attendees who self-identify as male; female; or are of non-binary gender identification

boot_camp_attendees_df.Gender.value_counts()
# Out:
# male           496
# female         326
# genderqueer      6
# trans            3
# agender          2
# Name: Gender, dtype: int64

# %%
# Calculate percentage of respondents who attended a bootcamp

percent_attendees=total_attendees/respondents*100
percent_attendees
# Out:
# 6.101152368758003

# %%
# Calculate percentage of respondents belonging to each gender

percent_gender=reduced_svyclean_df.Gender.value_counts()/respondents*100
percent_gender
# Out:
# male           68.924456
# female         18.181818
# genderqueer     0.422535
# agender         0.243278
# trans           0.230474
# Name: Gender, dtype: float64

# %%
# Calculate percentage of attendees with a school degree

percent_schl_degree= attendees_schl_degree/total_attendees*100
percent_schl_degree
# Out:
# 87.30325288562435

# %%
# Calculate average post-bootcamp salary

Bootcamp_avg_salary=boot_camp_attendees_df['BootcampPostSalary'].mean()
Bootcamp_avg_salary
# Out:
# 63740.50606060606

# %%
# Create a new table consolodating above calculations

Summary_Bootcamp=pd.DataFrame({
    'Total_Respondents':[respondents],
    'Total_attended_Bcamp':[total_attendees],
    'Percent_attendees':[percent_attendees],
    'Avg_age':[avg_age_attendees],
    'School_degree':[attendees_schl_degree],
    'Percent_school_degree':[percent_schl_degree],
    'Avg_Salary':[Bootcamp_avg_salary],
    'Gender':[percent_gender]
})

Summary_Bootcamp = Summary_Bootcamp.round(2)

Summary_Bootcamp
# Out:
#    Total_Respondents  Total_attended_Bcamp  Percent_attendees  Avg_age  \
# 0              15620                   953                6.1    31.07
#
#    School_degree  Percent_school_degree  Avg_Salary  \
# 0            832                   87.3    63740.51
#
#                                               Gender
# 0  male           68.924456
# female         18.181...

# %%
# Improve formatting before outputting spreadsheet

Summary_Bootcamp["Percent_attendees"] =Summary_Bootcamp['Percent_attendees']
Summary_Bootcamp['Avg_age'] =Summary_Bootcamp['Avg_age']
Summary_Bootcamp['School_degree'] =Summary_Bootcamp['School_degree']
Summary_Bootcamp['Percent_school_degree'] =Summary_Bootcamp['Percent_school_degree'].map("{0:,.2f}%".format)
Summary_Bootcamp['Avg_Salary'] =Summary_Bootcamp['Avg_Salary'].map("${0:,.2f}".format)

Summary_Bootcamp
# Out:
#    Total_Respondents  Total_attended_Bcamp  Percent_attendees  Avg_age  \
# 0              15620                   953                6.1    31.07
#
#    School_degree Percent_school_degree  Avg_Salary  \
# 0            832                87.30%  $63,740.51
#
#                                               Gender
# 0  male           68.924456
# female         18.181...

# %%
# Export to Excel

Summary_Bootcamp.to_excel('output/Bootcamp_partA.xlsx')
